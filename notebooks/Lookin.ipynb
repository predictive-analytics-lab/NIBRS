# %%
import pandas as pd

# %%
data = pd.read_csv("../data/NIBRS_full_all2019_202012091928.csv")

# %%
pd.crosstab([data.dm_offender_race_ethnicity], data.arrest).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='dm_offender_race_ethnicity'>

# %%
    pd.crosstab([data.dm_offender_race_ethnicity, data.dm_victim_race_ethnicity, data.weapon_type], data.arre, normalize='index')
# Out:
# arrest                                                                 No  \
# dm_offender_race_ethnicity dm_victim_race_ethnicity weapon_type
# black                      black                    firearm      0.672776
#                                                     none         0.778952
#                                                     object       0.617172
#                                                     unknown      0.625809
#                            hispanic/latino          firearm      0.765391
#                                                     none         0.760837
#                                                     object       0.601072
#                                                     unknown      0.624606
#                            other/mixed              firearm      0.685393
#                                                     none         0.784267
#                                                     object       0.598677
# ...

# %%
pd.crosstab([data.dm_offender_race_ethnicity, data.weapon_type], data.arrest_type, normalize='index')
# Out:
# arrest_type                             No Arrest   On View  Summoned / Cited  \
# dm_offender_race_ethnicity weapon_type
# black                      firearm       0.676477  0.146265          0.015429
#                            none          0.765982  0.113322          0.027897
#                            object        0.603659  0.213495          0.037977
#                            unknown       0.614465  0.193817          0.041408
# hispanic/latino            firearm       0.681943  0.197525          0.015124
#                            none          0.727584  0.142536          0.046951
#                            object        0.541522  0.285904          0.065163
#                            unknown       0.557177  0.258821          0.065952
# other/mixed                firearm       0.552301  0.343096          0.016736
#                            none          0.615309  0.237134          0.059609
# ...

# %%
pd.set_option('display.max_rows', 500)

pd.crosstab([data.dm_offender_race_ethnicity, data.relationship_type], data.arrest, normalize="index")
# Out:
# arrest                                              No       Yes
# dm_offender_race_ethnicity relationship_type
# black                      family             0.591442  0.408558
#                            known              0.661057  0.338943
#                            stranger           0.678138  0.321862
#                            unknown            0.727165  0.272835
# hispanic/latino            family             0.534055  0.465945
#                            known              0.602208  0.397792
#                            stranger           0.600282  0.399718
#                            unknown            0.687217  0.312783
# other/mixed                family             0.419919  0.580081
#                            known              0.494587  0.505413
#                            stranger           0.506419  0.493581
#                            unknown            0.590164  0.409836
# unknown                    family             0.564852  0.435148
# ...
