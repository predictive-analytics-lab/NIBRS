# %%
import pandas as pd

# %%
data = pd.read_csv("../data/NIBRS_202011301746.csv")

# %%
pd.crosstab([data.dm_offender_race], data.arrest).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='dm_offender_race'>

# %%
pd.crosstab([data.dm_offender_race], data.arrest, normalize='index')
# Out:
# arrest                  No       Yes
# dm_offender_race
# black             0.722353  0.277647
# other             0.680551  0.319449
# unknown           0.904480  0.095520
# white             0.669236  0.330764

# %%
pd.set_option('display.max_rows', 500)

pd.crosstab([data.dm_offender_race, data.dm_victim_race, data.relationship_type], data.arrest, normalize="index")
# Out:
# arrest                                                   No       Yes
# dm_offender_race dm_victim_race relationship_type
# black            black          family             0.646169  0.353831
#                                 known              0.770312  0.229687
#                                 stranger           0.770548  0.229452
#                                 unknown            0.861991  0.138009
#                  other          family             0.651376  0.348624
#                                 known              0.788991  0.211009
#                                 stranger           0.790123  0.209877
#                                 unknown            0.829897  0.170103
#                  unknown        family             0.621622  0.378378
#                                 known              0.764045  0.235955
#                                 stranger           0.520833  0.479167
#                                 unknown            0.761905  0.238095
# ...
